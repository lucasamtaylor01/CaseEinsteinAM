# %%
from pathlib import Path
import pandas as pd
import plotly.express as px

# %%
data_file = Path("..") / "model" / "SUPERSTORE_DATASET_CLUSTERING.csv"
df = pd.read_csv(data_file, sep=",")

# %%
df.head()
# Out:
#   CUSTOMER_ID  ORDER_DATE       SHIP_MODE SUB_CATEGORY         CATEGORY  \
# 0    AA-10315  2019-03-31  STANDARD CLASS   APPLIANCES  OFFICE SUPPLIES
# 1    AA-10375  2019-04-21  STANDARD CLASS      BINDERS  OFFICE SUPPLIES
# 2    AA-10480  2019-05-04        SAME DAY  FURNISHINGS        FURNITURE
# 3    AA-10645  2019-12-01     FIRST CLASS  FURNISHINGS        FURNITURE
# 4    AB-10015  2019-02-18  STANDARD CLASS      STORAGE  OFFICE SUPPLIES
#
#     REGION   SEGMENT  NET_SALES   PROFIT  CLUSTER
# 0     WEST  CONSUMER   204.7000  28.8658        1
# 1     WEST  CONSUMER  1171.1996  91.3899        3
# 2     EAST  CONSUMER   357.4148  63.0594        5
# 3     EAST  CONSUMER   291.2400  38.4204        5
# 4  CENTRAL  CONSUMER    59.1680   2.9553        1
